# %% [markdown]
# ### Apply serial, diverging and converging principles to your graph
# ##### 1. For graph from 13.1.a. apply serial, diverging and converging principles to selected sets of nodes. Check whether your expectation of data flow in the graph follow the principles.

# %% [markdown]
# - Serial connection
#
# ![image.png](attachment:image.png)
#
#
# - jest tak że informacja przepływa - wiemy że mamy grypę to skutkiem grypy jest zapalenie płuc, które wpływa na wynik rtg. Jednak samo zapalenie płuc nie wpływa w żaden sposób na wynik rtg. Gdy znamy stan bezpośredniej przyczyny (zapalenie płuc), informacja o przyczynie pierwotnej (grypa) nie wnosi już nic nowego do przewidywania skutku (RTG).

# %% [markdown]
# - Diverging
#
# ![image.png](attachment:image.png)
#
# - Skutki nie są ze sobą połączone - mają wspólną przyczynę. Wiemy, że przyczyna wystąpiła, skutki są od siebie niezależne, jeden nie wpływa na drugi. Oba są spowodowane przez Covid ale kaszel nie wpływa na ustratę węchu.

# %% [markdown]
# - Converging
#
# ![image.png](attachment:image.png)
#
# - Mamy 2 skutki, które powodują to samo. Informacja o wystąpieniu wspólnego skutku sprawia, że wykluczenie jednej przyczyny zwiększa prawdopodobieństwo wystąpienia drugiej

# %% [markdown]
# ### Modify simple structure
# ##### 1. You were asked to create a simple network for flu diagnosis. You should include two symptoms: coughing and sneezing. You assume that once presence (or absence) of flu is confirmed, observing one symptom does not influence belief in presence of the other symptom.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 2. After consulting with a doctor, you learn that the above assumption is not correct. Alter the structure of the network accordingly.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - przed konsultacją z lekarzem wiedzieliśmy że grypa powoduje kichanie i kaszel. Oba mogą wystąpić niezależnie czy już jeden jest czy go nie ma.
# - po konsultacji wiemy że jeden symptom wpływa na drugi. Są od siebie w jakiś sposób zależne. Z wiedzy domowej wiemy, że duży katar potrafi spływać do gardła co powoduje wystąpienie kaszlu.
