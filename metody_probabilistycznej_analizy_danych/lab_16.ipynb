# %% [markdown]
# ### Enter some numbers.
#
# ##### 1. Using GeNIe, enter numerical specification for the Holmes network (lecture slide 138). Take into account the hints below. Assume the network covers data for 24 hours. Note: some numbers may still be missing! Use your own ideas to plausibly fill the voids.
# - The monitoring company claims the alarm catches 95% of burglaries.
# - Someone living in the same neighbourhood said that this type of alarm is triggered by 1 out of 5 earthquakes.
# - Local radio station is not very reliable, it will sometime report earthquake even if it occurred in another state. On the other hand, they never failed to inform about an earthquake if it occurred in the neighbourhood.
# - Watson is somewhat deaf, but he is definitely not a prankster.
# - For the past 2 years, there were 50 house robberies in the neighbourhood. It consists of 1350 houses.
# - Expect 3 earthquakes each year

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - P(Burglary = True): 50 włamań / 1350 domów / 730 dni = 0.00005
# - P(Burglary = False): 1 - P(Burglary = False) = 1 - 0.00005 = 0.99995
#
# - P(Earthquake = True): 3 trzęsienia / 365 dni = 0.0082
# - P(Earthquake = False): 1 - P(Earthquake = True) = 1 - 0.0082 = 0.9918
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - radio zawsze prawidłowo informuje jak jest trzęsienie ziemi ale czasem zdarza im się poinformować fałszywie
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - alarm
#
# Firma mówi że ma 95% skuteczności - wyje gdy jest włamanie ale wiadomo że co 5 trzęsienie ziemi się sam włącza (20%) - przy braku włamań i braku trzęsień ziemi wyje rzadko (10%) ale jak jest włamamie i trzęsienie ziemi to wyje na pewno na 95%
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - telefon od Watsona
#
# Jak jest alarm to dzwoni (chyba że nie usłyszy lub go nie ma w domu) ale też jest moim przyjaciem to może sobie zadzwonić w wolnym czasie pogadać.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Wnioski**

# %% [markdown]
# przy włamaniu i braku trzęsienia ziemi Watson zadzwoni na 88%
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Wiadomo że jest trzęsienie ziemi ale niewiadomo czy jest włamanie
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - jeżeli radio nadaje komunikat że jest trzęsienie ziemi to jego prawdopodobieństwo jest 0.92
#
# ![image.png](attachment:image.png)
