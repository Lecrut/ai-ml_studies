# %% [markdown]
# ### Utilise field data.
# ##### Alarm manufacturer made available data describing operation of its products installed in the neighbourhood (Holmes alarm data.txt). Each record contains state of randomly chosen device, supplemented by information whether burglary or earthquake happened immediately before. Use these data to update the parameters of the Holmes network.
# - Assume the new data and the data based on which the current network was created are of equal importance.
# - Remember that only the Alarm node should be updated.
# - How the parameters of the node changed?

# %% [markdown]
# - po nauczeniu zmienił się tylko węzeł alarm
#
# ![image.png](attachment:image.png)
#
# - reszta węzłów pozostała bez zmian
#
# - przed zmianą wyglądał tak
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - teraz bez dowodów prawdopodobieństwo alarmu jest bliskie 0
#
# ![image.png](attachment:image.png)
#
# - telefon od whatsona jest połowa szans
#
# ![image-2.png](attachment:image-2.png)
